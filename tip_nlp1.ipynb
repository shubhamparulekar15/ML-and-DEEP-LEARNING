# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = [
             'I LOVE MY DOG',
             'I LOVE MY CAT'
             'YOU LOVE MY CAT'
             'DO YOU THHINK MY DOG IS AMAZING'
             'YOU LOVE MY DOG'
]

tokenizer = Tokenizer(num_words = 100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=5)
print("\nWord Index = " , word_index)
print("\nSequences = " , sequences)
print("\nPadded Sequences:",padded)
#print(padded)
# Out:
# Word Index =  {'<OOV>': 1, 'my': 2, 'love': 3, 'dog': 4, 'i': 5, 'catyou': 6, 'catdo': 7, 'you': 8, 'thhink': 9, 'is': 10, 'amazingyou': 11}
#
# Sequences =  [[5, 3, 2, 4], [5, 3, 2, 6, 3, 2, 7, 8, 9, 2, 4, 10, 11, 3, 2, 4]]
#
# Padded Sequences: [[ 0  5  3  2  4]
#  [10 11  3  2  4]]
